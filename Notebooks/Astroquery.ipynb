# %% [markdown]
# #### Astroquery
#
# https://astroquery.readthedocs.org/en/latest/gallery.html
# https://astroquery.readthedocs.org/en/latest/#available-services

# %%
img = np.zeros((nmos502.shape[0], nmos502.shape[1], 3), dtype=float)
img[:,:,0] = nmos502
#img[:,:,1] = nmos656
#img[:,:,2] = nmos673
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-410f0db94f08> in <module>()
# ----> 1 img = np.zeros((nmos502.shape[0], nmos502.shape[1], 3), dtype=float)
#       2 img[:,:,0] = nmos502
#       3 #img[:,:,1] = nmos656
#       4 #img[:,:,2] = nmos673
#
# NameError: name 'np' is not defined

# %%
from astroquery.irsa import Irsa
import astropy.units as u
Irsa.query_region('m42', catalog='wise_allsky_4band_p3as_psd', radius=10*u.arcmin)
# Out:
# <Table masked=True length=500>
#     designation        ra     dec   ...       angle          id
#                       deg     deg   ...        deg
#        object       float64 float64 ...      float64       object
# ------------------- ------- ------- ... ------------------ ------
# J053530.49-051529.3  83.877  -5.258 ...          23.856493      0
# J053539.34-051636.0  83.914  -5.277 ... 40.016219999999997      1
# J053452.59-051655.2  83.719  -5.282 ...         317.378962      2
# J053518.81-051729.1  83.828  -5.291 ... 5.6364660000000004      3
# J053525.87-051831.7  83.858  -5.309 ... 25.742743999999998      4
# J053537.20-051710.1  83.905  -5.286 ... 39.722054999999997      5
# J053450.40-051604.0  83.710  -5.268 ... 318.41530699999998      6
# J053518.52-051338.3  83.827  -5.227 ... 2.9882529999999998      7
# J053537.92-051701.5  83.908  -5.284 ... 40.028815000000002      8
#                 ...     ...     ... ...                ...    ...
# ...
